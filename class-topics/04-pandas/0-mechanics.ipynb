# %%
import pandas as pd

# %%
df = pd.read_csv("data/facebook/reaction_counts.csv")

# %%
df.columns
# Out:
# Index(['status_id', 'status_message', 'link_name', 'status_type',
#        'status_link', 'status_published', 'num_reactions', 'num_comments',
#        'num_shares', 'num_likes', 'num_loves', 'num_wows', 'num_hahas',
#        'num_sads', 'num_angrys'],
#       dtype='object')

# %%
df.head()
# Out:
#                         status_id  \
# 0  153080620724_10157915294545725
# 1  153080620724_10157914483265725
# 2  153080620724_10157913199155725
# 3  153080620724_10157912962325725
# 4  153080620724_10157912187170725
#
#                                       status_message  \
# 0  Beautiful evening in Wisconsin- THANK YOU for ...
# 1  The State Department's quid pro quo scheme pro...
# 2  Crooked Hillary's State Department colluded wi...
# 3  JournoCash: Media gives $382,000 to Clinton, $...
# 4  Exclusive: "O'Keefe Video Sting Exposes 'Bird-...
#
#                                            link_name status_type  \
# 0                                    Timeline Photos       photo
# 1                                                NaN       video
# 2                                                NaN       video
# 3  JournoCash: Media gives $382,000 to Clinton, $...        link
# 4  O'Keefe Reveals 'Bird-Dogging' to Incite Viole...        link
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4160 entries, 0 to 4159
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         4160 non-null   object
#  1   status_message    3793 non-null   object
#  2   link_name         2715 non-null   object
#  3   status_type       4160 non-null   object
#  4   status_link       2983 non-null   object
#  5   status_published  4160 non-null   object
#  6   num_reactions     4160 non-null   int64
#  7   num_comments      4160 non-null   int64
#  8   num_shares        4160 non-null   int64
#  9   num_likes         4160 non-null   int64
#  10  num_loves         4160 non-null   int64
#  11  num_wows          4160 non-null   int64
#  12  num_hahas         4160 non-null   int64
#  13  num_sads          4160 non-null   int64
#  14  num_angrys        4160 non-null   int64
# dtypes: int64(9), object(6)
# memory usage: 487.6+ KB

# %%
df.describe()
# Out:
#        num_reactions   num_comments     num_shares     num_likes  \
# count   4.160000e+03    4160.000000    4160.000000  4.160000e+03
# mean    5.615623e+04    5110.989904    7559.597115  5.304939e+04
# std     6.476866e+04   10733.173912   25141.062901  6.117745e+04
# min     7.000000e+00       3.000000       0.000000  7.000000e+00
# 25%     9.306250e+03     816.000000     337.500000  9.277250e+03
# 50%     4.259600e+04    3456.000000    3146.500000  3.996450e+04
# 75%     8.010175e+04    6255.000000    7562.500000  7.551600e+04
# max     1.117712e+06  319745.000000  812775.000000  1.117712e+06
#
#           num_loves      num_wows     num_hahas      num_sads    num_angrys
# count   4160.000000   4160.000000   4160.000000   4160.000000   4160.000000
# mean    1852.617548    167.143510    405.795192    129.878365    545.483654
# std     3710.897388    591.494191   2402.593975    961.554830   2532.714733
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# ...

# %%
df["num_shares"]
# Out:
# 0         359
# 1       17653
# 2       32594
# 3        5082
# 4       17087
#         ...
# 4155        3
# 4156        6
# 4157        2
# 4158        0
# 4159        9
# Name: num_shares, Length: 4160, dtype: int64

# %%
df.loc[4156]
# Out:
# status_id                                    153080620724_96770601006
# status_message      - Who do you think will be fired on Celebrity ...
# link_name                                                         NaN
# status_type                                                    status
# status_link                                                       NaN
# status_published                                  2009-04-19T17:18:16
# num_reactions                                                     140
# num_comments                                                      111
# num_shares                                                          6
# num_likes                                                         140
# num_loves                                                           0
# num_wows                                                            0
# num_hahas                                                           0
# ...

# %%
df[["num_reactions", "num_hahas"]]
# Out:
#       num_reactions  num_hahas
# 0              6813         17
# 1             33768         75
# 2             85627        330
# 3             22696        241
# 4             40729        154
# ...             ...        ...
# 4155            152          0
# 4156            140          0
# 4157            137          0
# 4158            136          0
# 4159            209          0
#
# [4160 rows x 2 columns]

# %%
df["num_hahas"].to_frame()
# Out:
#       num_hahas
# 0            17
# 1            75
# 2           330
# 3           241
# 4           154
# ...         ...
# 4155          0
# 4156          0
# 4157          0
# 4158          0
# 4159          0
#
# [4160 rows x 1 columns]

# %%
df.loc[[4155, 4158]]
# Out:
#                      status_id  \
# 4155  153080620724_86348879816
# 4158  153080620724_71666378535
#
#                                          status_message link_name status_type  \
# 4155  - Check out the official website for Donald Tr...       NaN      status
# 4158  Watch Donald J. Trump on Larry King Live: http...       NaN      status
#
#      status_link     status_published  num_reactions  num_comments  \
# 4155         NaN  2009-04-20T08:44:07            152            43
# 4158         NaN  2009-04-16T10:05:34            136            66
#
#       num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 4155           3        152          0         0          0         0
# 4158           0        136          0         0          0         0
#
#       num_angrys
# 4155           0
# 4158           0

# %%
df.loc[[4155, 4158], :]
# Out:
#                      status_id  \
# 4155  153080620724_86348879816
# 4158  153080620724_71666378535
#
#                                          status_message link_name status_type  \
# 4155  - Check out the official website for Donald Tr...       NaN      status
# 4158  Watch Donald J. Trump on Larry King Live: http...       NaN      status
#
#      status_link     status_published  num_reactions  num_comments  \
# 4155         NaN  2009-04-20T08:44:07            152            43
# 4158         NaN  2009-04-16T10:05:34            136            66
#
#       num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 4155           3        152          0         0          0         0
# 4158           0        136          0         0          0         0
#
#       num_angrys
# 4155           0
# 4158           0

# %%
df.loc[:, ["status_id", "link_name"]]
# Out:
#                            status_id  \
# 0     153080620724_10157915294545725
# 1     153080620724_10157914483265725
# 2     153080620724_10157913199155725
# 3     153080620724_10157912962325725
# 4     153080620724_10157912187170725
# ...                              ...
# 4155        153080620724_86348879816
# 4156        153080620724_96770601006
# 4157        153080620724_85435041544
# 4158        153080620724_71666378535
# 4159       153080620724_162861335065
#
#                                               link_name
# 0                                       Timeline Photos
# 1                                                   NaN
# 2                                                   NaN
# 3     JournoCash: Media gives $382,000 to Clinton, $...
# 4     O'Keefe Reveals 'Bird-Dogging' to Incite Viole...
# ...                                                 ...
# 4155                                                NaN
# 4156                                                NaN
# ...

# %%
df[df["num_shares"] >= 3000]
# Out:
#                            status_id  \
# 1     153080620724_10157914483265725
# 2     153080620724_10157913199155725
# 3     153080620724_10157912962325725
# 4     153080620724_10157912187170725
# 5     153080620724_10157911744440725
# ...                              ...
# 3724  153080620724_10152237431910725
# 3758  153080620724_10152199183755725
# 3759    153080620724_490937194272914
# 3763  153080620724_10152194743380725
# 3780  153080620724_10152175316785725
#
#                                          status_message  \
# 1     The State Department's quid pro quo scheme pro...
# 2     Crooked Hillary's State Department colluded wi...
# 3     JournoCash: Media gives $382,000 to Clinton, $...
# 4     Exclusive: "O'Keefe Video Sting Exposes 'Bird-...
# 5     Of course there is large scale voter fraud hap...
# ...                                                 ...
# 3724  Our country is now in serious and unprecedente...
# 3758              As stated, here is the press release.
# ...

# %%
df.loc[df["num_shares"] >= 3000]
# Out:
#                            status_id  \
# 1     153080620724_10157914483265725
# 2     153080620724_10157913199155725
# 3     153080620724_10157912962325725
# 4     153080620724_10157912187170725
# 5     153080620724_10157911744440725
# ...                              ...
# 3724  153080620724_10152237431910725
# 3758  153080620724_10152199183755725
# 3759    153080620724_490937194272914
# 3763  153080620724_10152194743380725
# 3780  153080620724_10152175316785725
#
#                                          status_message  \
# 1     The State Department's quid pro quo scheme pro...
# 2     Crooked Hillary's State Department colluded wi...
# 3     JournoCash: Media gives $382,000 to Clinton, $...
# 4     Exclusive: "O'Keefe Video Sting Exposes 'Bird-...
# 5     Of course there is large scale voter fraud hap...
# ...                                                 ...
# 3724  Our country is now in serious and unprecedente...
# 3758              As stated, here is the press release.
# ...

# %%
df.loc[df["num_shares"] >= 3000, :]
# Out:
#                            status_id  \
# 1     153080620724_10157914483265725
# 2     153080620724_10157913199155725
# 3     153080620724_10157912962325725
# 4     153080620724_10157912187170725
# 5     153080620724_10157911744440725
# ...                              ...
# 3724  153080620724_10152237431910725
# 3758  153080620724_10152199183755725
# 3759    153080620724_490937194272914
# 3763  153080620724_10152194743380725
# 3780  153080620724_10152175316785725
#
#                                          status_message  \
# 1     The State Department's quid pro quo scheme pro...
# 2     Crooked Hillary's State Department colluded wi...
# 3     JournoCash: Media gives $382,000 to Clinton, $...
# 4     Exclusive: "O'Keefe Video Sting Exposes 'Bird-...
# 5     Of course there is large scale voter fraud hap...
# ...                                                 ...
# 3724  Our country is now in serious and unprecedente...
# 3758              As stated, here is the press release.
# ...

# %%
new_df = df.assign(
    likes_share_ratio=lambda df: df["num_likes"] / df["num_shares"]
)

# %%
new_df
# Out:
#                            status_id  \
# 0     153080620724_10157915294545725
# 1     153080620724_10157914483265725
# 2     153080620724_10157913199155725
# 3     153080620724_10157912962325725
# 4     153080620724_10157912187170725
# ...                              ...
# 4155        153080620724_86348879816
# 4156        153080620724_96770601006
# 4157        153080620724_85435041544
# 4158        153080620724_71666378535
# 4159       153080620724_162861335065
#
#                                          status_message  \
# 0     Beautiful evening in Wisconsin- THANK YOU for ...
# 1     The State Department's quid pro quo scheme pro...
# 2     Crooked Hillary's State Department colluded wi...
# 3     JournoCash: Media gives $382,000 to Clinton, $...
# 4     Exclusive: "O'Keefe Video Sting Exposes 'Bird-...
# ...                                                 ...
# 4155  - Check out the official website for Donald Tr...
# 4156  - Who do you think will be fired on Celebrity ...
# ...

# %%
df.set_index("status_id").reset_index()
# Out:
#                            status_id  \
# 0     153080620724_10157915294545725
# 1     153080620724_10157914483265725
# 2     153080620724_10157913199155725
# 3     153080620724_10157912962325725
# 4     153080620724_10157912187170725
# ...                              ...
# 4155        153080620724_86348879816
# 4156        153080620724_96770601006
# 4157        153080620724_85435041544
# 4158        153080620724_71666378535
# 4159       153080620724_162861335065
#
#                                          status_message  \
# 0     Beautiful evening in Wisconsin- THANK YOU for ...
# 1     The State Department's quid pro quo scheme pro...
# 2     Crooked Hillary's State Department colluded wi...
# 3     JournoCash: Media gives $382,000 to Clinton, $...
# 4     Exclusive: "O'Keefe Video Sting Exposes 'Bird-...
# ...                                                 ...
# 4155  - Check out the official website for Donald Tr...
# 4156  - Who do you think will be fired on Celebrity ...
# ...

# %%
df.set_index("status_type").loc["photo", :]
# Out:
#                                   status_id  \
# status_type
# photo        153080620724_10157915294545725
# photo        153080620724_10157907607315725
# photo        153080620724_10157898932735725
# photo        153080620724_10157897465130725
# photo        153080620724_10157893664950725
# ...                                     ...
# photo        153080620724_10150876741720725
# photo        153080620724_10150816231630725
# photo        153080620724_10150370919630725
# photo        153080620724_10150142451675725
# photo             153080620724_488852245724
#
#                                                 status_message  \
# status_type
# photo        Beautiful evening in Wisconsin- THANK YOU for ...
# photo        Animals representing Hillary Clinton and Dems ...
# photo        The MOVEMENT in Portsmouth, New Hampshire w/ 7...
# photo        Executive privilege to hide #POTUS emails on C...
# photo        Thank you Charlotte, North Carolina! We are go...
# ...

# %%
df.loc[df["status_type"] == "photo"]
# Out:
#                            status_id  \
# 0     153080620724_10157915294545725
# 10    153080620724_10157907607315725
# 20    153080620724_10157898932735725
# 23    153080620724_10157897465130725
# 27    153080620724_10157893664950725
# ...                              ...
# 3975  153080620724_10150876741720725
# 3986  153080620724_10150816231630725
# 4057  153080620724_10150370919630725
# 4099  153080620724_10150142451675725
# 4107       153080620724_488852245724
#
#                                          status_message        link_name  \
# 0     Beautiful evening in Wisconsin- THANK YOU for ...  Timeline Photos
# 10    Animals representing Hillary Clinton and Dems ...  Timeline Photos
# 20    The MOVEMENT in Portsmouth, New Hampshire w/ 7...  Timeline Photos
# 23    Executive privilege to hide #POTUS emails on C...  Timeline Photos
# 27    Thank you Charlotte, North Carolina! We are go...  Timeline Photos
# ...
